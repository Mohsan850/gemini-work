# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohsan850/gemini-work/blob/main/chartboard1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')
# Out:
# 'AIzaSyDEGzluE_zaRUVTvveLxz5mDMUP40VNt1U'

# %%
# !pip  install -q -U google.generativeai
import google.generativeai as genai
genai.configure(api_key="AIzaSyDEGzluE_zaRUVTvveLxz5mDMUP40VNt1U")

# %%
model_name = "gemini-1.5-flash"
model=genai.GenerativeModel(model_name)

# %%
import PIL.Image as img
image=img.open("mohsan.jfif")
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x1280>

# %%
prompt="explain about image"
response=model.generate_content([image,prompt])
print(response.text)
# Out:
# That's a photo of a man sitting at a desk, working on a laptop computer.
#
#
# Here's a breakdown of the image:
#
# * **The Man:** He appears to be young to middle-aged, with a beard and wearing a light blue shirt, a dark vest, and a traditional-style cap (possibly a Pakol). He has a somewhat pensive or thoughtful expression, with his hand resting on his cheek.
#
# * **The Setting:** He's seated at a simple wooden desk in what looks like an office or classroom setting. A white board or wall is visible in the background.
#
# * **The Technology:** A laptop computer is open on the desk in front of him. A computer mouse and a pen are also on the desk. The laptop appears to be closed, indicating he might be taking a break from working.
#
# * **Overall Impression:** The image conveys a sense of quiet concentration or perhaps contemplation. The setting suggests a professional or educational context. The man's attire hints at cultural background.

# %%
# Out:
# Let's break down these terms and parameters commonly used in large language models (LLMs) like those powering ChatGPT:
#
# **1. Messages:**
#
# * **Definition:**  In the context of chat-based interfaces, "messages" are the units of communication exchanged between the user and the model.  Each message typically contains a prompt, question, instruction, or response.  In some APIs, messages may include system messages (setting the context or persona), user messages (the user's input), and assistant messages (the model's output).  The sequence of messages forms the conversation history.
#
#
# **2. Model:**
#
# * **Definition:** This refers to the specific large language model being used.  Each model (e.g., GPT-3.5-turbo, GPT-4) has its own architecture, training data, and capabilities.  Different models will generate different responses to the same prompt due to variations in their training and design.
#
#
# **3. Max Completion Tokens:**
#
# ...
